# %%
# Celda 1: Importaciones y configuración
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Importamos las funciones del notebook anterior desde nuestro nuevo archivo!
from utils_trayectorias import (
    extraer_origen_destino_final, 
    asignar_periodo
)

# %%
# Celda 2: Carga de datos y exploración
RUTA_EXCEL = "C:/Users/micag/Documents/RedesHospitales/data/revision_dfs.xlsx"
trayectorias = pd.read_excel(RUTA_EXCEL, sheet_name=2)

print("--- TODAS LAS COLUMNAS DISPONIBLES ---")
for col in trayectorias.columns:
    print(f"- {col}")

# Una vez que identifiques la columna de causa (ej: 'motivo_egreso'), 
# reemplazala en el string de abajo y descomentá las líneas:
# columna_causa = 'tu_columna_aqui'
# print(f"\n--- VALORES ÚNICOS DE {columna_causa} ---")
# print(trayectorias[columna_causa].value_counts(dropna=False))
# Out:
# --- TODAS LAS COLUMNAS DISPONIBLES ---
# - paciente_id
# - ruta_hospitales_str
# - ruta_tipos_str
# - ruta_tipos_num_str
# - ruta_complejidad_str
# - ruta_hospitales_array
# - ruta_tipos_array
# - ruta_tipos_num_array
# - ruta_complejidad_array
# - hospital_final
# - tipo_final_txt
# - tipo_final_num
# - complejidad_final
# - cantidad_traslados
# - hubo_alerta
# - dias_alerta_array
# - fecha_ingreso_trayectoria

# %%
trayectorias
# Out:
#      paciente_id                         ruta_hospitales_str  \
# 0              1                     UPA 17 - QU -> Oñativia
# 1              4                     Oñativia -> UPA 17 - QU
# 2           AA31    UPA 5 - AB -> Módulo Hospitalario 9 - AB
# 3           AA47    UPA 5 - AB -> Módulo Hospitalario 9 - AB
# 4           AB13  UPA 11 - FV -> Módulo Hospitalario 11 - FV
# ...          ...                                         ...
# 1588        ZY87    Módulo Hospitalario 9 - AB -> UPA 5 - AB
# 1589        ZZ37  UPA 11 - FV -> Módulo Hospitalario 11 - FV
# 1590        ZZ63  UPA 11 - FV -> Módulo Hospitalario 11 - FV
# 1591        ZZ79  UPA 11 - FV -> Módulo Hospitalario 11 - FV
# 1592        ZZ99    UPA 5 - AB -> Módulo Hospitalario 9 - AB
#
#                   ruta_tipos_str ruta_tipos_num_str ruta_complejidad_str  \
# 0     intermedias -> intermedias             2 -> 2               0 -> 2
# 1     intermedias -> intermedias             2 -> 2               2 -> 0
# ...
